# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./data.csv')

# %%
data.head()
# Out:
#    sl_no  gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1       0  67.00   Others  91.00   Others  Commerce     58.00
# 1      2       0  79.33  Central  78.33   Others   Science     77.48
# 2      3       0  65.00  Central  68.00  Central      Arts     64.00
# 3      4       0  56.00  Central  52.00  Central   Science     52.00
# 4      5       0  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
data.corr()
# Out:
# C:\Users\manan\AppData\Local\Temp\ipykernel_8736\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#              sl_no    gender     ssc_p     hsc_p  degree_p   etest_p  \
# sl_no     1.000000 -0.074306 -0.078155 -0.085711 -0.088281  0.063636
# gender   -0.074306  1.000000  0.068969  0.021334  0.173217 -0.084294
# ssc_p    -0.078155  0.068969  1.000000  0.511472  0.538404  0.261993
# hsc_p    -0.085711  0.021334  0.511472  1.000000  0.434206  0.245113
# degree_p -0.088281  0.173217  0.538404  0.434206  1.000000  0.224470
# etest_p   0.063636 -0.084294  0.261993  0.245113  0.224470  1.000000
# mba_p     0.022327  0.300531  0.388478  0.354823  0.402364  0.218055
# salary    0.063764 -0.158912  0.035330  0.076819 -0.019272  0.178307
#
#              mba_p    salary
# ...

# %%
data.columns
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
#        'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
#        'status', 'salary'],
#       dtype='object')

# %%
data['gender'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
data.groupby(['gender']).mean()['ssc_p'].plot(kind='pie', autopct='%.2f', title="Average middle school percentage according to gender.")
# Out:
# C:\Users\manan\AppData\Local\Temp\ipykernel_8736\3928063762.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['gender']).mean()['ssc_p'].plot(kind='pie', autopct='%.2f', title="Average middle school percentage according to gender.")
# <AxesSubplot: title={'center': 'Average middle school percentage according to gender.'}, ylabel='ssc_p'>

# %%
data.groupby(['gender']).mean()['hsc_p'].plot(kind='pie', title="Average high school percentage according to gender.", autopct='%.2f')
# Out:
# C:\Users\manan\AppData\Local\Temp\ipykernel_8736\3476130287.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['gender']).mean()['hsc_p'].plot(kind='pie', title="Average high school percentage according to gender.", autopct='%.2f')
# <AxesSubplot: title={'center': 'Average high school percentage according to gender.'}, ylabel='hsc_p'>

# %%
data.groupby(['gender']).mean()['degree_p'].plot(kind='pie', title="Average undergraduate percentage according to gender.", autopct='%.2f')
# Out:
# C:\Users\manan\AppData\Local\Temp\ipykernel_8736\1872156642.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['gender']).mean()['degree_p'].plot(kind='pie', title="Average undergraduate percentage according to gender.", autopct='%.2f')
# <AxesSubplot: title={'center': 'Average undergraduate percentage according to gender.'}, ylabel='degree_p'>

# %%
data.groupby(['gender']).mean()['etest_p'].plot(kind='pie', autopct='%.2f', title="Average Employability test percentage percentage according to gender.")
# Out:
# C:\Users\manan\AppData\Local\Temp\ipykernel_8736\3271609753.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['gender']).mean()['etest_p'].plot(kind='pie', autopct='%.2f', title="Average Employability test percentage percentage according to gender.")
# <AxesSubplot: title={'center': 'Average Employability test percentage percentage according to gender.'}, ylabel='etest_p'>

# %%
# data.groupby(['gender']).sum().plot(kind='bar', y='salary', color=['#699FA1','#df7027'], title="Average salary based on genders.")
data.groupby(['gender']).mean().plot(kind='bar', y='salary', color=['#699FA1','#df7027'], title="Average salary based on genders.")
# Out:
# C:\Users\manan\AppData\Local\Temp\ipykernel_8736\636112306.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['gender']).mean().plot(kind='bar', y='salary', color=['#699FA1','#df7027'], title="Average salary based on genders.")
# <AxesSubplot: title={'center': 'Average salary based on genders.'}, xlabel='gender'>

# %%
data.groupby(['specialisation']).mean().plot(kind='bar', y='degree_p', color=['#699FA1','#df7027'], title="Average salary based on undergraduate percentage.")
# Out:
# C:\Users\manan\AppData\Local\Temp\ipykernel_8736\2623027199.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['specialisation']).mean().plot(kind='bar', y='degree_p', color=['#699FA1','#df7027'], title="Average salary based on undergraduate percentage.")
# <AxesSubplot: title={'center': 'Average salary based on undergraduate percentage.'}, xlabel='specialisation'>

# %%
data.groupby(['specialisation']).mean().plot(kind='bar', y='etest_p', color=['#699FA1','#df7027'], title="Average salary based on the employability test percentage.")
# Out:
# C:\Users\manan\AppData\Local\Temp\ipykernel_8736\678134623.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['specialisation']).mean().plot(kind='bar', y='etest_p', color=['#699FA1','#df7027'], title="Average salary based on the employability test percentage.")
# <AxesSubplot: title={'center': 'Average salary based on the employability test percentage.'}, xlabel='specialisation'>

# %%
data.groupby(['gender']).mean().plot(kind='pie', y='mba_p', autopct='%.2f', title="Average MBA percentage based on Genders.")
# Out:
# C:\Users\manan\AppData\Local\Temp\ipykernel_8736\1577697051.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['gender']).mean().plot(kind='pie', y='mba_p', autopct='%.2f', title="Average MBA percentage based on Genders.")
# <AxesSubplot: title={'center': 'Average MBA percentage based on Genders.'}, ylabel='mba_p'>

# %%
data.groupby(['workex']).mean().plot(kind='pie', y='salary', title="Average salary based on work experience.")
# Out:
# C:\Users\manan\AppData\Local\Temp\ipykernel_8736\555186299.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['workex']).mean().plot(kind='pie', y='salary', title="Average salary based on work experience.")
# <AxesSubplot: title={'center': 'Average salary based on work experience.'}, ylabel='salary'>

# %%
data.groupby(['specialisation']).mean().plot(kind='bar', y='salary', color=['#699FA1','#df7027'], title="Average salary based on specialisation.")
# Out:
# C:\Users\manan\AppData\Local\Temp\ipykernel_8736\1289638892.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['specialisation']).mean().plot(kind='bar', y='salary', color=['#699FA1','#df7027'], title="Average salary based on specialisation.")
# <AxesSubplot: title={'center': 'Average salary based on specialisation.'}, xlabel='specialisation'>

# %%
data.replace([0, 1],['M', 'F'], inplace=True)

# %%
data.corr()
# Out:
# C:\Users\manan\AppData\Local\Temp\ipykernel_8736\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#              ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# ssc_p     1.000000  0.511472  0.538404  0.261993  0.388478  0.035330
# hsc_p     0.511472  1.000000  0.434206  0.245113  0.354823  0.076819
# degree_p  0.538404  0.434206  1.000000  0.224470  0.402364 -0.019272
# etest_p   0.261993  0.245113  0.224470  1.000000  0.218055  0.178307
# mba_p     0.388478  0.354823  0.402364  0.218055  1.000000  0.175013
# salary    0.035330  0.076819 -0.019272  0.178307  0.175013  1.000000

# %%
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3        M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 210      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 211      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 212      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 213      F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
# 214      M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
data.corr()
# Out:
# C:\Users\manan\AppData\Local\Temp\ipykernel_8736\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.063764
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.035330
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.076819
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364 -0.019272
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.178307
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.175013
# salary    0.063764  0.035330  0.076819 -0.019272  0.178307  0.175013  1.000000

# %%
sn.heatmap(data.corr(), annot=True)
plt.show()
# Out:
# C:\Users\manan\AppData\Local\Temp\ipykernel_8736\2380143740.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sn.heatmap(data.corr(), annot=True)

# %%
data.plot.scatter(x='degree_p', y='mba_p', c='salary', title="Relation between degree percentage, MBA percentage, and Salary.")
# Out:
# <AxesSubplot: title={'center': 'Relation between degree percentage, MBA percentage, and Salary.'}, xlabel='degree_p', ylabel='mba_p'>

# %%
data.groupby(['specialisation']).sum().plot(kind='box', y='salary', color=['#699FA1','#df7027'], title="Average salary based on specialisation.")
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
#        'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
#        'status', 'salary'],
#       dtype='object')

# %%
data.plot.scatter(x='mba_p', y='etest_p', c='salary', title="Relation between exprience test percentage, MBA percentage, and Salary.")
# Out:
# <AxesSubplot: title={'center': 'Relation between exprience test percentage, MBA percentage, and Salary.'}, xlabel='mba_p', ylabel='etest_p'>
